# %%
from cryo_sbi import CryoEmSimulator
import torch
import matplotlib.pyplot as plt

# %%
Simulator = CryoEmSimulator("config_file.json")
img = Simulator.simulator(torch.tensor([0]))
plt.imshow(img)
# Out:
# protein_models/hsp90_models.npy

# %%
img_noise = torch.distributions.normal.Normal(0, 1).sample(img.shape)

# %%
torch.mean(img_noise - torch.mean(img_noise)), torch.std(img_noise)
# Out:
# (tensor(1.1409e-08), tensor(1.0014))

# %%
import numpy as np
np.mean(np.random.randn(128, 128))
# Out:
# 0.014008724330456817
